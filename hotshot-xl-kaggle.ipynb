# %% [markdown]
# <a href="https://www.kaggle.com/code/pogscafe/hotshot-xl?scriptVersionId=146065178" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
BASEPATH = '/kaggle/working'

# %cd $BASEPATH
# !git clone https://github.com/wandaweb/Hotshot-XL
HOTSHOT_PATH = BASEPATH + '/Hotshot-XL'
# %cd $HOTSHOT_PATH
# !pip install -r requirements.txt

import os
os.makedirs('lora', exist_ok=True)
os.makedirs('input', exist_ok=True)
os.makedirs('output', exist_ok=True)

# !apt install -y imagemagick
# Out:
# /kaggle/working
# fatal: destination path 'Hotshot-XL' already exists and is not an empty directory.
# /kaggle/working/Hotshot-XL
# Collecting git+https://github.com/sberbank-ai/Real-ESRGAN.git (from -r requirements.txt (line 63))
#   Cloning https://github.com/sberbank-ai/Real-ESRGAN.git to /tmp/pip-req-build-vpfz1af7
#   Running command git clone --filter=blob:none --quiet https://github.com/sberbank-ai/Real-ESRGAN.git /tmp/pip-req-build-vpfz1af7
#   Resolved https://github.com/sberbank-ai/Real-ESRGAN.git to commit 362a0316878f41dbdfbb23657b450c3353de5acf
#   Preparing metadata (setup.py) ... done
# Collecting accelerate==0.23.0 (from -r requirements.txt (line 1))
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 6.7 MB/s eta 0:00:0000:01
# Requirement already satisfied: appdirs==1.4.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: certifi==2023.7.22 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (2023.7.22)
# Collecting charset-normalizer==3.3.0 (from -r requirements.txt (line 4))
#   Downloading charset_normalizer-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: click==8.1.7 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (8.1.7)
# Collecting cmake==3.27.6 (from -r requirements.txt (line 6))
#   Downloading cmake-3.27.6-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (26.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 39.4 MB/s eta 0:00:0000:0100:01
# Collecting decorator==4.4.2 (from -r requirements.txt (line 7))
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting diffusers==0.21.4 (from -r requirements.txt (line 8))
#   Downloading diffusers-0.21.4-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 64.5 MB/s eta 0:00:00
# Requirement already satisfied: docker-pycreds==0.4.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (0.4.0)
# Collecting einops==0.7.0 (from -r requirements.txt (line 10))
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.9 MB/s eta 0:00:00
# Collecting filelock==3.12.4 (from -r requirements.txt (line 11))
#   Downloading filelock-3.12.4-py3-none-any.whl (11 kB)
# Collecting fsspec==2023.9.2 (from -r requirements.txt (line 12))
#   Downloading fsspec-2023.9.2-py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.4/173.4 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: gitdb==4.0.10 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (4.0.10)
# Collecting GitPython==3.1.37 (from -r requirements.txt (line 14))
#   Downloading GitPython-3.1.37-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub==0.16.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (0.16.4)
# Requirement already satisfied: idna==3.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (3.4)
# Collecting imageio==2.31.5 (from -r requirements.txt (line 17))
#   Downloading imageio-2.31.5-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 23.8 MB/s eta 0:00:00
# Collecting imageio-ffmpeg==0.4.9 (from -r requirements.txt (line 18))
#   Downloading imageio_ffmpeg-0.4.9-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 37.5 MB/s eta 0:00:0000:0100:01
# Collecting importlib-metadata==6.8.0 (from -r requirements.txt (line 19))
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: Jinja2==3.1.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (3.1.2)
# Collecting lit==17.0.2 (from -r requirements.txt (line 21))
#   Downloading lit-17.0.2.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.6/154.6 kB 12.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: MarkupSafe==2.1.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (2.1.3)
# Collecting moviepy==1.0.3 (from -r requirements.txt (line 23))
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 28.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: mpmath==1.3.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (1.3.0)
# Requirement already satisfied: networkx==3.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (3.1)
# Collecting numpy==1.26.0 (from -r requirements.txt (line 26))
#   Downloading numpy-1.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 48.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu11==11.10.3.66 (from -r requirements.txt (line 27))
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from -r requirements.txt (line 28))
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 58.4 MB/s eta 0:00:0000:010:01m
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from -r requirements.txt (line 29))
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 56.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from -r requirements.txt (line 30))
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 55.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from -r requirements.txt (line 31))
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu11==10.9.0.58 (from -r requirements.txt (line 32))
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu11==10.2.10.91 (from -r requirements.txt (line 33))
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 8.6 MB/s eta 0:00:00:00:0100:01
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from -r requirements.txt (line 34))
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 10.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from -r requirements.txt (line 35))
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 5.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu11==2.14.3 (from -r requirements.txt (line 36))
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 6.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu11==11.7.91 (from -r requirements.txt (line 37))
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 2.1 MB/s eta 0:00:00ta 0:00:01
# Collecting packaging==23.2 (from -r requirements.txt (line 38))
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 396.6 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pathtools==0.1.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (0.1.2)
# Collecting Pillow==10.0.1 (from -r requirements.txt (line 40))
#   Downloading Pillow-10.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 2.4 MB/s eta 0:00:00:00:0100:01
# Collecting proglog==0.1.10 (from -r requirements.txt (line 41))
#   Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Collecting protobuf==4.24.3 (from -r requirements.txt (line 42))
#   Downloading protobuf-4.24.3-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 23.9 MB/s eta 0:00:00
# Collecting psutil==5.9.5 (from -r requirements.txt (line 43))
#   Downloading psutil-5.9.5-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.1/282.1 kB 26.7 MB/s eta 0:00:00
# Collecting PyYAML==6.0.1 (from -r requirements.txt (line 44))
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 44.5 MB/s eta 0:00:00
# Collecting regex==2023.10.3 (from -r requirements.txt (line 45))
#   Downloading regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.9/773.9 kB 48.9 MB/s eta 0:00:00
# Requirement already satisfied: requests==2.31.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 46)) (2.31.0)
# Requirement already satisfied: safetensors==0.3.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 47)) (0.3.3)
# Collecting sentry-sdk==1.31.0 (from -r requirements.txt (line 48))
#   Downloading sentry_sdk-1.31.0-py2.py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 21.8 MB/s eta 0:00:00
# Collecting setproctitle==1.3.3 (from -r requirements.txt (line 49))
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: six==1.16.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 50)) (1.16.0)
# Collecting smmap==5.0.1 (from -r requirements.txt (line 51))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: sympy==1.12 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 52)) (1.12)
# Collecting tokenizers==0.14.0 (from -r requirements.txt (line 53))
#   Downloading tokenizers-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 64.2 MB/s eta 0:00:00:00:01
# Collecting torch==2.0.1 (from -r requirements.txt (line 54))
#   Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 1.5 MB/s eta 0:00:0000:0100:01
# Collecting torchvision==0.15.2 (from -r requirements.txt (line 55))
#   Downloading torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 83.1 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: tqdm==4.66.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 56)) (4.66.1)
# Collecting transformers==4.34.0 (from -r requirements.txt (line 57))
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 64.6 MB/s eta 0:00:00:00:0100:01
# Collecting triton==2.0.0 (from -r requirements.txt (line 58))
#   Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 5.1 MB/s eta 0:00:00:00:0100:01
# Collecting typing_extensions==4.8.0 (from -r requirements.txt (line 59))
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting urllib3==2.0.6 (from -r requirements.txt (line 60))
#   Downloading urllib3-2.0.6-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 11.5 MB/s eta 0:00:00
# Collecting wandb==0.15.11 (from -r requirements.txt (line 61))
#   Downloading wandb-0.15.11-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 72.0 MB/s eta 0:00:00
# Collecting zipp==3.17.0 (from -r requirements.txt (line 62))
#   Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from imageio-ffmpeg==0.4.9->-r requirements.txt (line 18)) (68.0.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->-r requirements.txt (line 27)) (0.40.0)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (from RealESRGAN==1.0->-r requirements.txt (line 63)) (4.8.0.76)
# Building wheels for collected packages: lit, moviepy, RealESRGAN
#   Building wheel for lit (pyproject.toml) ... done
#   Created wheel for lit: filename=lit-17.0.2-py3-none-any.whl size=93257 sha256=8d7a674ca859456cd5212bc0daab6f2f45fbb5047de3db1d2bb27525a4eb3e9b
#   Stored in directory: /root/.cache/pip/wheels/3a/ff/73/ce1a12d89231e9ac175fb6493ee1fcc8768e85ee3bea4b98b2
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110730 sha256=d1543fdffe9d2f3ff2a0e675345cb251f69c8a11da5438c851dc7c4621d41fa0
#   Stored in directory: /root/.cache/pip/wheels/96/32/2d/e10123bd88fbfc02fed53cc18c80a171d3c87479ed845fa7c1
#   Building wheel for RealESRGAN (setup.py) ... done
#   Created wheel for RealESRGAN: filename=RealESRGAN-1.0-py3-none-any.whl size=9107 sha256=ff1ec36ec406dc12fe2b7b24f5a41825ffe305acc5c6690becf35c0f3321b6ec
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ap43sbdv/wheels/dd/a3/7d/774508ed192455403be294c8a6c4ad1c83dde8fcdd8903e64a
# Successfully built lit moviepy RealESRGAN
# Installing collected packages: lit, cmake, zipp, urllib3, typing_extensions, smmap, setproctitle, regex, PyYAML, psutil, protobuf, proglog, Pillow, packaging, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, numpy, imageio-ffmpeg, fsspec, filelock, einops, decorator, charset-normalizer, sentry-sdk, nvidia-cusolver-cu11, nvidia-cudnn-cu11, importlib-metadata, imageio, moviepy, GitPython, wandb, tokenizers, diffusers, transformers, triton, torch, torchvision, RealESRGAN, accelerate
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.15.0
#     Uninstalling zipp-3.15.0:
#       Successfully uninstalled zipp-3.15.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.15
#     Uninstalling urllib3-1.26.15:
#       Successfully uninstalled urllib3-1.26.15
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.6.3
#     Uninstalling typing_extensions-4.6.3:
#       Successfully uninstalled typing_extensions-4.6.3
#   Attempting uninstall: smmap
#     Found existing installation: smmap 5.0.0
#     Uninstalling smmap-5.0.0:
#       Successfully uninstalled smmap-5.0.0
#   Attempting uninstall: setproctitle
#     Found existing installation: setproctitle 1.3.2
#     Uninstalling setproctitle-1.3.2:
#       Successfully uninstalled setproctitle-1.3.2
#   Attempting uninstall: regex
#     Found existing installation: regex 2023.6.3
#     Uninstalling regex-2023.6.3:
#       Successfully uninstalled regex-2023.6.3
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.3
#     Uninstalling psutil-5.9.3:
#       Successfully uninstalled psutil-5.9.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.9.0
#     Uninstalling fsspec-2023.9.0:
#       Successfully uninstalled fsspec-2023.9.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.12.2
#     Uninstalling filelock-3.12.2:
#       Successfully uninstalled filelock-3.12.2
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.1.0
#     Uninstalling charset-normalizer-3.1.0:
#       Successfully uninstalled charset-normalizer-3.1.0
#   Attempting uninstall: sentry-sdk
#     Found existing installation: sentry-sdk 1.30.0
#     Uninstalling sentry-sdk-1.30.0:
#       Successfully uninstalled sentry-sdk-1.30.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.7.0
#     Uninstalling importlib-metadata-6.7.0:
#       Successfully uninstalled importlib-metadata-6.7.0
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.31.1
#     Uninstalling imageio-2.31.1:
#       Successfully uninstalled imageio-2.31.1
#   Attempting uninstall: GitPython
#     Found existing installation: GitPython 3.1.31
#     Uninstalling GitPython-3.1.31:
#       Successfully uninstalled GitPython-3.1.31
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.15.9
#     Uninstalling wandb-0.15.9:
#       Successfully uninstalled wandb-0.15.9
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.3
#     Uninstalling tokenizers-0.13.3:
#       Successfully uninstalled tokenizers-0.13.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.33.0
#     Uninstalling transformers-4.33.0:
#       Successfully uninstalled transformers-4.33.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0
#     Uninstalling torch-2.0.0:
#       Successfully uninstalled torch-2.0.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1
#     Uninstalling torchvision-0.15.1:
#       Successfully uninstalled torchvision-0.15.1
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.22.0
#     Uninstalling accelerate-0.22.0:
#       Successfully uninstalled accelerate-0.22.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.0 which is incompatible.
# apache-beam 2.46.0 requires protobuf<4,>3.12.2, but you have protobuf 4.24.3 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# beatrix-jupyterlab 2023.621.222118 requires jupyter-server~=1.16, but you have jupyter-server 2.6.0 which is incompatible.
# botocore 1.31.17 requires urllib3<1.27,>=1.25.4, but you have urllib3 2.0.6 which is incompatible.
# cmudict 1.0.13 requires importlib-metadata<6.0.0,>=5.1.0, but you have importlib-metadata 6.8.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# distributed 2023.7.1 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# fitter 1.6.0 requires pandas<3.0.0,>=2.0.3, but you have pandas 2.0.2 which is incompatible.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2023.9.2 which is incompatible.
# google-auth 2.20.0 requires urllib3<2.0, but you have urllib3 2.0.6 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 23.2 which is incompatible.
# google-cloud-bigquery 2.34.4 requires protobuf<4.0.0dev,>=3.12.0, but you have protobuf 4.24.3 which is incompatible.
# google-cloud-bigtable 1.7.3 requires protobuf<4.0.0dev, but you have protobuf 4.24.3 which is incompatible.
# google-cloud-pubsub 2.17.1 requires grpcio<2.0dev,>=1.51.3, but you have grpcio 1.51.1 which is incompatible.
# google-cloud-vision 2.8.0 requires protobuf<4.0.0dev,>=3.19.0, but you have protobuf 4.24.3 which is incompatible.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# kfp 2.0.1 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# kfp 2.0.1 requires protobuf<4,>=3.13.0, but you have protobuf 4.24.3 which is incompatible.
# kfp 2.0.1 requires urllib3<2.0.0, but you have urllib3 2.0.6 which is incompatible.
# kfp-pipeline-spec 0.2.2 requires protobuf<4,>=3.13.0, but you have protobuf 4.24.3 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.26.0 which is incompatible.
# opentelemetry-api 1.18.0 requires importlib-metadata~=6.0.0, but you have importlib-metadata 6.8.0 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.26.0 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.2 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# s3fs 2023.9.0 requires fsspec==2023.9.0, but you have fsspec 2023.9.2 which is incompatible.
# tensorboardx 2.6 requires protobuf<4,>=3.8.0, but you have protobuf 4.24.3 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.26.0 which is incompatible.
# tensorflow-metadata 0.14.0 requires protobuf<4,>=3.7, but you have protobuf 4.24.3 which is incompatible.
# tensorflow-transform 0.14.0 requires protobuf<4,>=3.7, but you have protobuf 4.24.3 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 2.0.1 which is incompatible.
# woodwork 0.26.0 requires numpy<1.25.0,>=1.22.0, but you have numpy 1.26.0 which is incompatible.
# ydata-profiling 4.3.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.26.0 which is incompatible.
# ydata-profiling 4.3.1 requires scipy<1.11,>=1.4.1, but you have scipy 1.11.2 which is incompatible.
# Successfully installed GitPython-3.1.37 Pillow-10.0.1 PyYAML-6.0.1 RealESRGAN-1.0 accelerate-0.23.0 charset-normalizer-3.3.0 cmake-3.27.6 decorator-4.4.2 diffusers-0.21.4 einops-0.7.0 filelock-3.12.4 fsspec-2023.9.0 imageio-2.31.5 imageio-ffmpeg-0.4.9 importlib-metadata-6.8.0 lit-17.0.2 moviepy-1.0.3 numpy-1.25.2 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 packaging-23.2 proglog-0.1.10 protobuf-4.21.12 psutil-5.9.5 regex-2023.10.3 sentry-sdk-1.31.0 setproctitle-1.3.3 smmap-5.0.1 tokenizers-0.14.0 torch-2.0.1 torchvision-0.15.2 transformers-4.34.0 triton-2.0.0 typing_extensions-4.6.3 urllib3-1.26.16 wandb-0.15.11 zipp-3.15.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript gsfonts
#   imagemagick-6-common imagemagick-6.q16 libde265-0 libdjvulibre-text
#   libdjvulibre21 libfftw3-double3 libgs9 libgs9-common libheif1 libidn12
#   libijs-0.35 libilmbase25 libjbig2dec0 libjxr-tools libjxr0 liblqr-1-0
#   libmagickcore-6.q16-6 libmagickcore-6.q16-6-extra libmagickwand-6.q16-6
#   libnetpbm10 libopenexr25 libwebpdemux2 libwmflite-0.2-7 netpbm poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre
#   ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng enscript gimp
#   gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance sane-utils
#   transfig ufraw-batch libfftw3-bin libfftw3-dev inkscape poppler-utils
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
#   | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript gsfonts
#   imagemagick imagemagick-6-common imagemagick-6.q16 libde265-0
#   libdjvulibre-text libdjvulibre21 libfftw3-double3 libgs9 libgs9-common
#   libheif1 libidn12 libijs-0.35 libilmbase25 libjbig2dec0 libjxr-tools libjxr0
#   liblqr-1-0 libmagickcore-6.q16-6 libmagickcore-6.q16-6-extra
#   libmagickwand-6.q16-6 libnetpbm10 libopenexr25 libwebpdemux2
#   libwmflite-0.2-7 netpbm poppler-data
# 0 upgraded, 31 newly installed, 0 to remove and 74 not upgraded.
# Need to get 26.5 MB of archives.
# After this operation, 93.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1build1 [1805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-double3 amd64 3.3.8-2ubuntu8 [770 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libde265-0 amd64 1.0.8-1 [243 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libheif1 amd64 1.12.0-2build1 [196 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Ign:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebpdemux2 amd64 1.2.2-2ubuntu0.22.04.1
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick-6-common all 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [63.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickcore-6.q16-6 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [1788 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickwand-6.q16-6 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [328 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2171 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Err:6 http://security.ubuntu.com/ubuntu jammy-updates/main amd64 libwebpdemux2 amd64 1.2.2-2ubuntu0.22.04.1
#   404  Not Found [IP: 185.125.190.39 80]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6367 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9-common all 9.55.0~dfsg1-0ubuntu5.4 [752 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1 [60.0 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libijs-0.35 amd64 0.35-15build2 [16.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjbig2dec0 amd64 0.19-3build2 [64.7 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9 amd64 9.55.0~dfsg1-0ubuntu5.4 [5032 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ghostscript amd64 9.55.0~dfsg1-0ubuntu5.4 [49.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.5 [3120 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick-6.q16 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [224 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [14.6 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdjvulibre-text all 3.5.28-2build2 [50.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdjvulibre21 amd64 3.5.28-2build2 [624 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase25 amd64 2.5.7-2 [175 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr0 amd64 1.2~git20170615.f752187-5 [174 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr-tools amd64 1.2~git20170615.f752187-5 [16.0 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr25 amd64 2.5.7-1 [780 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwmflite-0.2-7 amd64 0.2.12-5ubuntu1 [68.9 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickcore-6.q16-6-extra amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3 [70.1 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnetpbm10 amd64 2:10.0-15.4 [59.1 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 netpbm amd64 2:10.0-15.4 [1007 kB]
# Fetched 26.5 MB in 2s (12.2 MB/s)
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/libw/libwebp/libwebpdemux2_1.2.2-2ubuntu0.22.04.1_amd64.deb  404  Not Found [IP: 185.125.190.39 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?

# %%
# %cd $HOTSHOT_PATH

#Parameters

batch_size = 1 # @param {type:"slider", min:1, max:50, step:1}
positive_prompt = 'snow white, gorgeous girl with black hair, pale skin, with red lipstick, in a long dress, dancing in a cyberpunk city square, octane render, dramatic lighting, dark, slow motion, colorful, disney, pixar style, centered, looking at viewer' #@param {type:"string"}
negative_prompt = 'blurry, fog' #@param {type:"string"}
seed = -1 #@param {type:"integer"}
width = 416 #@param {type:"integer"}
height = 608 #@param {type:"integer"}
upscale = "2" #@param [0, 2, 4]
video_frames = 8 #@param {type:"integer"}
video_duration = 1000 #@param {type:"integer"}
steps = "40" #@param {type:"string"}
lora_file_name = '' #@param {type:"string"}
file_prefix = 'out_' #@param {type:"string"}
file_type = '.mp4' #@param [".mp4", ".gif"]
scheduler='EulerDiscreteScheduler' #@param ["EulerAncestralDiscreteScheduler", "EulerDiscreteScheduler"]

# Gif to video
gif_name = '' #@param {type:"string"}
control_type = 'depth' #@param ["depth", "canny"]
controlnet_conditioning_scale = 0.8 #@param {type:"number"}
control_guidance_start = 0.0 #@param {type:"number"}
control_guidance_end = 1.0 #@param {type:"number"}

# Resolutions quick reference

# | Width x Height | Ratio| Orientation |
# | --- | --- | --- |
# | 512 x 512 | 1 : 1 | Square |
# | 608 x 416 | 19 : 13 | Horizontal
# | 416 x 608 | 13 : 19 | Vertical
# | 672 x 384 | 7 : 4 | Horizontal
# | 384 x 672 | 4 : 7 | Vertical
# | 768 x 320 | 12 : 5 | Horizontal
# | 320 x 768 | 5 : 12 | Vertical

import datetime, random, os
from IPython.display import display, Image, HTML
from base64 import b64encode

videos = []

if seed == None or seed == -1:
  seed = random.randint(0, 18446744073709519871)

for i in range(batch_size):
  file_name=f'{file_prefix}{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}{file_type}'
  data_name=f'{file_prefix}{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}.txt'
  # Create the command
  cmd = f'''python inference.py \
   --prompt="{positive_prompt}" \
   --negative_prompt="{negative_prompt}" \
   --steps={steps} \
   --seed={seed} \
   --width={width} \
   --height={height} \
   --video_length={video_frames} \
   --video_duration={video_duration} \
   --scheduler="{scheduler}" \
   '''
  if upscale == '2' or upscale == '4':
    cmd += f'--upscale={upscale}  '
  if not lora_file_name == '':
    print('using lora')
    cmd += f'--lora="lora/{lora_file_name}"  '
  if not gif_name == '':
    cmd += f'''--gif=input/{gif_name} \
      --control_type={control_type} \
      --controlnet_conditioning_scale={controlnet_conditioning_scale} \
      --control_guidance_start={control_guidance_start} \
      --control_guidance_end={control_guidance_end} \
      '''

  cmd += f'--output="output/{file_name}"'

  # Execute command
  print(cmd)
  get_ipython().system(cmd);

  # Write command to file
  f = open('output/'+data_name, 'w')
  f.write(cmd)
  f.close()

  seed = random.randint(0, 18446744073709519871)
  videos.append('output/' + file_name)

# Show the results
print(str(videos))
result = ''
if file_type == '.gif':
  for v in videos:
    display(Image(filename=v, retina=True))
else:
  for v in videos:
      mp4 = open(v,'rb').read()
      data_url = 'data:video/mp4;base64,' + b64encode(mp4).decode()
      result += ('''
      <video width=400 controls loop>
        <source src="%s" type="video/mp4">
      </video>
      ''' % data_url)
HTML(result)
# Out:
# /kaggle/working/Hotshot-XL
# python inference.py    --prompt="snow white, gorgeous girl with black hair, pale skin, with red lipstick, in a long dress, dancing in a cyberpunk city square, octane render, dramatic lighting, dark, slow motion, colorful, disney, pixar style, centered, looking at viewer"    --negative_prompt="blurry, fog"    --steps=40    --seed=8029280712831418301    --width=416    --height=608    --video_length=8    --video_duration=1000    --scheduler="EulerDiscreteScheduler"    --upscale=2 \--output="output/out_20231011-024740.mp4"
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# Downloading (…)ain/model_index.json: 100%|█████| 579/579 [00:00<00:00, 3.09MB/s]
# Fetching 18 files:   0%|                                 | 0/18 [00:00<?, ?it/s]
# Downloading (…)okenizer_config.json: 100%|█████| 737/737 [00:00<00:00, 3.87MB/s]
#
# Downloading model.safetensors:   0%|                 | 0.00/492M [00:00<?, ?B/s]
#
# Downloading (…)cheduler_config.json: 100%|█████| 474/474 [00:00<00:00, 2.98MB/s]
# Fetching 18 files:  11%|██▊                      | 2/18 [00:00<00:02,  6.51it/s]
#
# Downloading model.safetensors:   0%|                | 0.00/2.78G [00:00<?, ?B/s]
#
#
# Downloading (…)_encoder/config.json: 100%|█████| 613/613 [00:00<00:00, 3.94MB/s]
#
#
#
# Downloading (…)ncoder_2/config.json: 100%|█████| 623/623 [00:00<00:00, 1.80MB/s]
#
#
#
# Downloading (…)tokenizer/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
#
#
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
#
# Downloading (…)tokenizer/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 15.5MB/s]
#
# Downloading model.safetensors:   2%|▏       | 10.5M/492M [00:00<00:07, 68.1MB/s]
#
#
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 472/472 [00:00<00:00, 2.01MB/s]
#
#
#
# Downloading (…)tokenizer/merges.txt: 100%|███| 525k/525k [00:00<00:00, 3.85MB/s]
#
# Downloading model.safetensors:   4%|▎       | 21.0M/492M [00:00<00:05, 79.4MB/s]
#
#
# Downloading (…)cial_tokens_map.json: 100%|█████| 460/460 [00:00<00:00, 1.93MB/s]
#
#
#
# Downloading (…)kenizer_2/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
# Downloading model.safetensors:   1%|        | 31.5M/2.78G [00:00<00:24, 113MB/s]
#
#
#
# Downloading (…)okenizer_config.json: 100%|█████| 725/725 [00:00<00:00, 2.86MB/s]
#
#
#
#
# Downloading (…)7cd1/vae/config.json: 100%|█████| 655/655 [00:00<00:00, 2.22MB/s]
#
#
#
#
# Downloading (…)cd1/unet/config.json: 100%|█| 1.73k/1.73k [00:00<00:00, 6.35MB/s]
#
# Downloading model.safetensors:   9%|▊        | 41.9M/492M [00:00<00:04, 110MB/s]
#
# Downloading model.safetensors:   2%|▏       | 52.4M/2.78G [00:00<00:20, 133MB/s]
#
#
# Downloading (…)kenizer_2/merges.txt: 100%|███| 525k/525k [00:00<00:00, 3.09MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0%|           | 0.00/335M [00:00<?, ?B/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/11.2G [00:00<?, ?B/s]
#
# Downloading model.safetensors:   3%|▏       | 73.4M/2.78G [00:00<00:18, 148MB/s]
#
# Downloading model.safetensors:   3%|▎       | 94.4M/2.78G [00:00<00:16, 164MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3%|  | 10.5M/335M [00:00<00:05, 60.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0%| | 10.5M/11.2G [00:00<03:05, 60.4MB/s]
#
# Downloading model.safetensors:   4%|▎        | 115M/2.78G [00:00<00:17, 152MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0%| | 21.0M/11.2G [00:00<02:48, 66.5MB/s]
# Downloading model.safetensors:  13%|█       | 62.9M/492M [00:00<00:06, 62.7MB/s]
#
# Downloading model.safetensors:   5%|▍        | 136M/2.78G [00:00<00:16, 157MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0%| | 31.5M/11.2G [00:00<02:30, 74.3MB/s]
#
# Downloading model.safetensors:   6%|▌        | 157M/2.78G [00:01<00:15, 168MB/s]
#
# Downloading model.safetensors:   6%|▌        | 178M/2.78G [00:01<00:14, 178MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6%|▏ | 21.0M/335M [00:00<00:11, 28.5MB/s]
# Downloading model.safetensors:  15%|█▏      | 73.4M/492M [00:01<00:08, 51.9MB/s]
#
# Downloading model.safetensors:   7%|▋        | 199M/2.78G [00:01<00:14, 177MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0%| | 41.9M/11.2G [00:00<03:55, 47.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9%|▏ | 31.5M/335M [00:00<00:07, 39.5MB/s]
# Downloading model.safetensors:  17%|█▎      | 83.9M/492M [00:01<00:06, 58.6MB/s]
#
# Downloading model.safetensors:   8%|▋        | 220M/2.78G [00:01<00:14, 180MB/s]
# Downloading model.safetensors:  19%|█▌      | 94.4M/492M [00:01<00:06, 65.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0%| | 52.4M/11.2G [00:00<03:26, 54.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16%|▎ | 52.4M/335M [00:00<00:04, 63.5MB/s]
#
# Downloading model.safetensors:   9%|▊        | 241M/2.78G [00:01<00:15, 164MB/s]
# Downloading model.safetensors:  21%|█▉       | 105M/492M [00:01<00:05, 72.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   1%| | 73.4M/11.2G [00:01<02:22, 78.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22%|▍ | 73.4M/335M [00:01<00:03, 82.1MB/s]
# Downloading model.safetensors:  26%|██▎      | 126M/492M [00:01<00:04, 89.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   1%| | 94.4M/11.2G [00:01<01:53, 97.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25%|▌ | 83.9M/335M [00:01<00:02, 84.4MB/s]
#
# Downloading model.safetensors:   9%|▊        | 262M/2.78G [00:01<00:21, 118MB/s]
# Downloading model.safetensors:  30%|██▉       | 147M/492M [00:01<00:03, 100MB/s]
#
#
# Downloading (…)ch_model.safetensors:  31%|▉  | 105M/335M [00:01<00:02, 94.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   1%|  | 115M/11.2G [00:01<01:58, 93.4MB/s]
#
# Downloading model.safetensors:  10%|▉        | 283M/2.78G [00:01<00:21, 118MB/s]
# Downloading model.safetensors:  34%|███▍      | 168M/492M [00:02<00:02, 111MB/s]
#
#
# Downloading (…)ch_model.safetensors:  38%|█▌  | 126M/335M [00:01<00:02, 103MB/s]
#
# Downloading model.safetensors:  11%|▉        | 304M/2.78G [00:02<00:21, 115MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   1%|  | 136M/11.2G [00:01<01:55, 96.3MB/s]
# Downloading model.safetensors:  38%|███▊      | 189M/492M [00:02<00:02, 102MB/s]
#
#
# Downloading (…)ch_model.safetensors:  44%|█▊  | 147M/335M [00:01<00:01, 113MB/s]
#
# Downloading model.safetensors:  12%|█        | 325M/2.78G [00:02<00:21, 116MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   1%|   | 157M/11.2G [00:01<01:48, 102MB/s]
#
#
# Downloading (…)ch_model.safetensors:  50%|██  | 168M/335M [00:01<00:01, 115MB/s]
# Downloading model.safetensors:  43%|████▎     | 210M/492M [00:02<00:02, 104MB/s]
#
# Downloading model.safetensors:  12%|█        | 346M/2.78G [00:02<00:20, 119MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   2%|   | 178M/11.2G [00:02<01:47, 103MB/s]
#
#
# Downloading (…)ch_model.safetensors:  56%|██▎ | 189M/335M [00:02<00:01, 116MB/s]
# Downloading model.safetensors:  47%|████▋     | 231M/492M [00:02<00:02, 107MB/s]
#
# Downloading model.safetensors:  13%|█▏       | 367M/2.78G [00:02<00:19, 122MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   2%|   | 199M/11.2G [00:02<01:42, 107MB/s]
#
#
# Downloading (…)ch_model.safetensors:  63%|██▌ | 210M/335M [00:02<00:01, 121MB/s]
#
# Downloading model.safetensors:  14%|█▎       | 388M/2.78G [00:02<00:19, 123MB/s]
# Downloading model.safetensors:  51%|█████     | 252M/492M [00:02<00:02, 102MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   2%|   | 220M/11.2G [00:02<01:37, 112MB/s]
#
#
# Downloading (…)ch_model.safetensors:  69%|██▊ | 231M/335M [00:02<00:00, 122MB/s]
# Downloading model.safetensors:  55%|█████▌    | 273M/492M [00:03<00:02, 107MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   2%|   | 241M/11.2G [00:02<01:32, 118MB/s]
#
# Downloading model.safetensors:  15%|█▎       | 409M/2.78G [00:03<00:22, 107MB/s]
#
#
# Downloading (…)ch_model.safetensors:  75%|███ | 252M/335M [00:02<00:00, 115MB/s]
# Downloading model.safetensors:  60%|█████▉    | 294M/492M [00:03<00:01, 111MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   2%|   | 262M/11.2G [00:02<01:32, 118MB/s]
#
# Downloading model.safetensors:  15%|█▍       | 430M/2.78G [00:03<00:21, 107MB/s]
#
#
# Downloading (…)ch_model.safetensors:  81%|███▎| 273M/335M [00:02<00:00, 119MB/s]
# Downloading model.safetensors:  64%|██████▍   | 315M/492M [00:03<00:01, 110MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3%|   | 283M/11.2G [00:02<01:33, 117MB/s]
#
# Downloading model.safetensors:  16%|█▍       | 451M/2.78G [00:03<00:21, 110MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88%|███▌| 294M/335M [00:03<00:00, 120MB/s]
# Downloading model.safetensors:  68%|██████▊   | 336M/492M [00:03<00:01, 105MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3%|   | 304M/11.2G [00:03<01:39, 110MB/s]
#
# Downloading model.safetensors:  17%|█▎      | 472M/2.78G [00:04<00:31, 72.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94%|██▊| 315M/335M [00:03<00:00, 62.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3%|  | 325M/11.2G [00:03<03:04, 58.9MB/s]
# Downloading model.safetensors:  72%|██████▌  | 357M/492M [00:04<00:02, 56.0MB/s]
#
# Downloading model.safetensors:  17%|█▍      | 482M/2.78G [00:04<00:41, 54.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97%|██▉| 325M/335M [00:04<00:00, 54.9MB/s]
#
# Downloading model.safetensors:  18%|█▍      | 493M/2.78G [00:04<00:43, 52.9MB/s]
# Downloading model.safetensors:  75%|██████▋  | 367M/492M [00:04<00:02, 53.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3%|  | 336M/11.2G [00:04<03:19, 54.5MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100%|███| 335M/335M [00:04<00:00, 79.3MB/s]
#
#
# Downloading model.safetensors:  18%|█▍      | 503M/2.78G [00:04<00:40, 55.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3%|  | 346M/11.2G [00:04<03:10, 57.2MB/s]
# Downloading model.safetensors:  77%|██████▉  | 377M/492M [00:04<00:02, 55.4MB/s]
#
# Downloading model.safetensors:  18%|█▍      | 514M/2.78G [00:04<00:37, 59.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3%|  | 357M/11.2G [00:04<02:58, 60.8MB/s]
# Downloading model.safetensors:  79%|███████  | 388M/492M [00:04<00:01, 58.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3%|  | 367M/11.2G [00:04<02:44, 66.1MB/s]
# Downloading model.safetensors:  81%|███████▎ | 398M/492M [00:05<00:01, 63.6MB/s]
#
# Downloading model.safetensors:  19%|█▌      | 524M/2.78G [00:05<00:36, 62.2MB/s]
#
# Downloading model.safetensors:  19%|█▌      | 535M/2.78G [00:05<00:32, 69.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3%|  | 377M/11.2G [00:04<02:38, 68.3MB/s]
# Downloading model.safetensors:  83%|███████▍ | 409M/492M [00:05<00:01, 67.5MB/s]
#
# Downloading model.safetensors:  20%|█▌      | 545M/2.78G [00:05<00:30, 73.8MB/s]
# Downloading model.safetensors:  85%|███████▋ | 419M/492M [00:05<00:01, 72.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3%|  | 388M/11.2G [00:04<02:28, 72.8MB/s]
#
# Downloading model.safetensors:  20%|█▌      | 556M/2.78G [00:05<00:29, 75.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4%|  | 398M/11.2G [00:04<02:25, 74.2MB/s]
# Downloading model.safetensors:  87%|███████▊ | 430M/492M [00:05<00:00, 74.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4%|  | 409M/11.2G [00:05<02:43, 66.0MB/s]
#
# Downloading model.safetensors:  20%|█▋      | 566M/2.78G [00:05<00:34, 64.4MB/s]
# Downloading model.safetensors:  89%|████████ | 440M/492M [00:05<00:00, 60.8MB/s]
#
# Downloading model.safetensors:  21%|█▋      | 577M/2.78G [00:05<00:38, 57.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4%|  | 419M/11.2G [00:05<03:08, 57.2MB/s]
# Downloading model.safetensors:  92%|████████▏| 451M/492M [00:05<00:00, 59.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4%|  | 430M/11.2G [00:05<03:17, 54.5MB/s]
#
# Downloading model.safetensors:  21%|█▋      | 587M/2.78G [00:06<00:40, 53.8MB/s]
# Downloading model.safetensors:  94%|████████▍| 461M/492M [00:06<00:00, 54.5MB/s]
#
# Downloading model.safetensors:  22%|█▋      | 598M/2.78G [00:06<00:42, 51.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4%|  | 440M/11.2G [00:05<03:33, 50.5MB/s]
# Downloading model.safetensors:  96%|████████▋| 472M/492M [00:06<00:00, 50.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4%|  | 451M/11.2G [00:05<03:03, 58.7MB/s]
#
# Downloading model.safetensors:  22%|█▊      | 608M/2.78G [00:06<00:38, 56.0MB/s]
# Downloading model.safetensors:  98%|████████▊| 482M/492M [00:06<00:00, 52.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4%|  | 461M/11.2G [00:06<02:52, 62.4MB/s]
#
# Downloading model.safetensors:  22%|█▊      | 619M/2.78G [00:06<00:35, 60.6MB/s]
# Downloading model.safetensors: 100%|█████████| 492M/492M [00:06<00:00, 58.6MB/s]
#
# Downloading model.safetensors: 100%|█████████| 492M/492M [00:06<00:00, 73.0MB/s]
#
#
#
#
# Fetching 18 files:  22%|█████▌                   | 4/18 [00:07<00:28,  2.06s/it]
#
# Downloading model.safetensors:  23%|█▊      | 640M/2.78G [00:06<00:28, 75.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4%|  | 482M/11.2G [00:06<02:30, 71.3MB/s]
#
# Downloading model.safetensors:  24%|█▉      | 661M/2.78G [00:06<00:22, 92.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4%|  | 503M/11.2G [00:06<02:01, 87.9MB/s]
#
# Downloading model.safetensors:  25%|█▉      | 682M/2.78G [00:07<00:21, 97.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5%|  | 524M/11.2G [00:06<02:03, 86.6MB/s]
#
# Downloading model.safetensors:  25%|█▉      | 692M/2.78G [00:07<00:23, 89.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5%|  | 535M/11.2G [00:06<02:04, 85.5MB/s]
#
# Downloading model.safetensors:  25%|██      | 703M/2.78G [00:07<00:24, 85.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5%|  | 545M/11.2G [00:07<02:23, 74.4MB/s]
#
# Downloading model.safetensors:  26%|██      | 713M/2.78G [00:07<00:27, 75.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5%|  | 556M/11.2G [00:07<02:22, 74.9MB/s]
#
# Downloading model.safetensors:  26%|██      | 724M/2.78G [00:07<00:26, 78.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5%|  | 566M/11.2G [00:07<02:13, 79.6MB/s]
#
# Downloading model.safetensors:  26%|██      | 734M/2.78G [00:07<00:25, 80.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5%|  | 577M/11.2G [00:07<02:07, 83.5MB/s]
#
# Downloading model.safetensors:  27%|██▏     | 744M/2.78G [00:08<00:23, 85.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5%|  | 587M/11.2G [00:07<02:02, 86.5MB/s]
#
# Downloading model.safetensors:  27%|██▏     | 755M/2.78G [00:08<00:23, 85.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5%|  | 608M/11.2G [00:07<01:49, 96.6MB/s]
#
# Downloading model.safetensors:  28%|██▏     | 776M/2.78G [00:08<00:21, 94.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6%|  | 619M/11.2G [00:07<01:49, 96.4MB/s]
#
# Downloading model.safetensors:  29%|██▌      | 797M/2.78G [00:08<00:18, 104MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6%|▏  | 640M/11.2G [00:08<01:42, 103MB/s]
#
# Downloading model.safetensors:  29%|██▋      | 818M/2.78G [00:08<00:17, 112MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6%|▏  | 661M/11.2G [00:08<01:37, 109MB/s]
#
# Downloading model.safetensors:  30%|██▋      | 839M/2.78G [00:08<00:16, 115MB/s]
#
# Downloading model.safetensors:  31%|██▊      | 860M/2.78G [00:08<00:15, 123MB/s]
#
# Downloading model.safetensors:  32%|██▊      | 881M/2.78G [00:09<00:14, 135MB/s]
#
# Downloading model.safetensors:  32%|██▉      | 902M/2.78G [00:09<00:12, 145MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6%|  | 682M/11.2G [00:08<02:46, 63.4MB/s]
#
# Downloading model.safetensors:  33%|██▉      | 923M/2.78G [00:09<00:12, 147MB/s]
#
# Downloading model.safetensors:  34%|███      | 944M/2.78G [00:09<00:12, 153MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6%|  | 692M/11.2G [00:08<02:51, 61.3MB/s]
#
# Downloading model.safetensors:  35%|███      | 965M/2.78G [00:09<00:12, 150MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6%|▏ | 713M/11.2G [00:09<02:33, 68.3MB/s]
#
# Downloading model.safetensors:  35%|███▏     | 986M/2.78G [00:09<00:12, 141MB/s]
#
# Downloading model.safetensors:  36%|██▉     | 1.01G/2.78G [00:09<00:11, 156MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6%|▏ | 724M/11.2G [00:09<02:38, 66.3MB/s]
#
# Downloading model.safetensors:  37%|██▉     | 1.03G/2.78G [00:10<00:10, 164MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7%|▏ | 734M/11.2G [00:09<02:33, 68.3MB/s]
#
# Downloading model.safetensors:  38%|███     | 1.05G/2.78G [00:10<00:10, 170MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7%|▏ | 744M/11.2G [00:09<02:22, 73.8MB/s]
#
# Downloading model.safetensors:  38%|███     | 1.07G/2.78G [00:10<00:09, 172MB/s]
#
# Downloading model.safetensors:  39%|███▏    | 1.09G/2.78G [00:10<00:09, 177MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7%|▏ | 765M/11.2G [00:09<02:03, 84.8MB/s]
#
# Downloading model.safetensors:  40%|███▏    | 1.11G/2.78G [00:10<00:09, 180MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7%|▏ | 786M/11.2G [00:10<01:54, 91.5MB/s]
#
# Downloading model.safetensors:  41%|███▎    | 1.13G/2.78G [00:10<00:08, 185MB/s]
#
# Downloading model.safetensors:  42%|███▎    | 1.15G/2.78G [00:10<00:08, 184MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7%|▏ | 797M/11.2G [00:10<02:01, 86.1MB/s]
#
# Downloading model.safetensors:  42%|███▍    | 1.17G/2.78G [00:10<00:08, 186MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7%|▏ | 807M/11.2G [00:10<02:08, 81.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7%|▏ | 818M/11.2G [00:10<02:01, 85.4MB/s]
#
# Downloading model.safetensors:  43%|███▍    | 1.20G/2.78G [00:11<00:11, 143MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7%|▏ | 828M/11.2G [00:10<02:11, 79.1MB/s]
#
# Downloading model.safetensors:  44%|███▌    | 1.22G/2.78G [00:11<00:11, 134MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7%|▏ | 839M/11.2G [00:10<02:12, 78.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8%|▏ | 849M/11.2G [00:10<02:12, 78.5MB/s]
#
# Downloading model.safetensors:  45%|███▌    | 1.24G/2.78G [00:11<00:13, 112MB/s]
#
# Downloading model.safetensors:  45%|███▌    | 1.26G/2.78G [00:11<00:13, 114MB/s]
#
# Downloading model.safetensors:  46%|███▋    | 1.28G/2.78G [00:11<00:12, 123MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8%|▏ | 860M/11.2G [00:11<03:30, 49.3MB/s]
#
# Downloading model.safetensors:  47%|███▋    | 1.30G/2.78G [00:11<00:11, 131MB/s]
#
# Downloading model.safetensors:  48%|███▊    | 1.32G/2.78G [00:12<00:10, 142MB/s]
#
# Downloading model.safetensors:  48%|███▊    | 1.34G/2.78G [00:12<00:09, 148MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8%|▏ | 870M/11.2G [00:11<04:26, 38.8MB/s]
#
# Downloading model.safetensors:  49%|███▉    | 1.36G/2.78G [00:12<00:09, 150MB/s]
#
# Downloading model.safetensors:  50%|███▉    | 1.38G/2.78G [00:12<00:08, 157MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8%|▏ | 881M/11.2G [00:11<04:14, 40.6MB/s]
#
# Downloading model.safetensors:  51%|████    | 1.41G/2.78G [00:12<00:09, 151MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8%|▏ | 891M/11.2G [00:12<03:53, 44.2MB/s]
#
# Downloading model.safetensors:  51%|████    | 1.43G/2.78G [00:12<00:09, 149MB/s]
#
# Downloading model.safetensors:  52%|████▏   | 1.45G/2.78G [00:12<00:08, 154MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8%|▏ | 902M/11.2G [00:12<03:57, 43.4MB/s]
#
# Downloading model.safetensors:  53%|████▏   | 1.47G/2.78G [00:13<00:08, 147MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8%|▏ | 912M/11.2G [00:12<03:30, 49.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8%|▏ | 923M/11.2G [00:12<02:59, 57.2MB/s]
#
# Downloading model.safetensors:  54%|████▎   | 1.49G/2.78G [00:13<00:09, 132MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8%|▏ | 933M/11.2G [00:12<02:38, 65.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8%|▏ | 944M/11.2G [00:12<02:23, 71.4MB/s]
#
# Downloading model.safetensors:  54%|████▎   | 1.51G/2.78G [00:13<00:10, 122MB/s]
#
# Downloading model.safetensors:  55%|████▍   | 1.53G/2.78G [00:13<00:09, 128MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9%|▏ | 954M/11.2G [00:13<02:39, 64.4MB/s]
#
# Downloading model.safetensors:  56%|████▍   | 1.55G/2.78G [00:13<00:09, 133MB/s]
#
# Downloading model.safetensors:  57%|████▌   | 1.57G/2.78G [00:13<00:08, 140MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9%|▏ | 965M/11.2G [00:13<03:30, 48.7MB/s]
#
# Downloading model.safetensors:  57%|████▌   | 1.59G/2.78G [00:13<00:08, 146MB/s]
#
# Downloading model.safetensors:  58%|████▋   | 1.61G/2.78G [00:14<00:07, 149MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9%|▏ | 975M/11.2G [00:13<03:19, 51.4MB/s]
#
# Downloading model.safetensors:  59%|████▋   | 1.64G/2.78G [00:14<00:07, 150MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9%|▏ | 986M/11.2G [00:13<03:02, 56.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9%|▏ | 996M/11.2G [00:13<02:40, 63.8MB/s]
#
# Downloading model.safetensors:  60%|████▊   | 1.66G/2.78G [00:14<00:07, 144MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9%| | 1.01G/11.2G [00:13<02:27, 69.3MB/s]
#
# Downloading model.safetensors:  60%|████▊   | 1.68G/2.78G [00:14<00:07, 140MB/s]
#
# Downloading model.safetensors:  61%|████▉   | 1.70G/2.78G [00:14<00:07, 149MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9%| | 1.03G/11.2G [00:14<02:19, 73.2MB/s]
#
# Downloading model.safetensors:  62%|████▉   | 1.72G/2.78G [00:14<00:06, 160MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9%| | 1.04G/11.2G [00:14<02:22, 71.2MB/s]
#
# Downloading model.safetensors:  63%|█████   | 1.74G/2.78G [00:14<00:06, 153MB/s]
#
# Downloading model.safetensors:  63%|█████   | 1.76G/2.78G [00:15<00:06, 158MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9%| | 1.05G/11.2G [00:14<02:46, 61.2MB/s]
#
# Downloading model.safetensors:  64%|█████▏  | 1.78G/2.78G [00:15<00:05, 166MB/s]
#
# Downloading model.safetensors:  65%|█████▏  | 1.80G/2.78G [00:15<00:05, 171MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9%| | 1.06G/11.2G [00:14<02:48, 60.3MB/s]
#
# Downloading model.safetensors:  66%|█████▎  | 1.82G/2.78G [00:15<00:05, 175MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  10%| | 1.07G/11.2G [00:14<02:28, 68.4MB/s]
#
# Downloading model.safetensors:  66%|█████▎  | 1.85G/2.78G [00:15<00:05, 178MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  10%| | 1.09G/11.2G [00:15<01:58, 85.2MB/s]
#
# Downloading model.safetensors:  67%|█████▎  | 1.87G/2.78G [00:15<00:05, 181MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  10%|▏ | 1.11G/11.2G [00:15<01:37, 104MB/s]
#
# Downloading model.safetensors:  68%|█████▍  | 1.89G/2.78G [00:15<00:05, 175MB/s]
#
# Downloading model.safetensors:  69%|█████▍  | 1.91G/2.78G [00:15<00:04, 179MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  10%|▏ | 1.13G/11.2G [00:15<01:32, 109MB/s]
#
# Downloading model.safetensors:  69%|█████▌  | 1.93G/2.78G [00:15<00:04, 176MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  10%|▏ | 1.15G/11.2G [00:15<01:26, 116MB/s]
#
# Downloading model.safetensors:  70%|█████▌  | 1.95G/2.78G [00:16<00:04, 179MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  10%|▏ | 1.17G/11.2G [00:15<01:19, 127MB/s]
#
# Downloading model.safetensors:  71%|█████▋  | 1.97G/2.78G [00:16<00:04, 166MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  11%|▏ | 1.20G/11.2G [00:15<01:20, 124MB/s]
#
# Downloading model.safetensors:  72%|█████▋  | 1.99G/2.78G [00:16<00:04, 157MB/s]
#
# Downloading model.safetensors:  72%|█████▊  | 2.01G/2.78G [00:16<00:05, 153MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  11%|▏ | 1.22G/11.2G [00:16<01:19, 125MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  11%|▏ | 1.24G/11.2G [00:16<01:18, 128MB/s]
#
# Downloading model.safetensors:  73%|█████▊  | 2.03G/2.78G [00:16<00:05, 140MB/s]
#
# Downloading model.safetensors:  74%|█████▉  | 2.06G/2.78G [00:16<00:05, 136MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  11%|▏ | 1.26G/11.2G [00:16<01:21, 122MB/s]
#
# Downloading model.safetensors:  75%|█████▉  | 2.08G/2.78G [00:17<00:05, 130MB/s]
#
# Downloading model.safetensors:  75%|██████  | 2.10G/2.78G [00:17<00:04, 138MB/s]
#
# Downloading model.safetensors:  76%|██████  | 2.12G/2.78G [00:17<00:04, 147MB/s]
#
# Downloading model.safetensors:  77%|██████▏ | 2.14G/2.78G [00:17<00:04, 146MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  11%| | 1.28G/11.2G [00:16<02:23, 69.1MB/s]
#
# Downloading model.safetensors:  78%|██████▏ | 2.16G/2.78G [00:17<00:04, 131MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  11%| | 1.29G/11.2G [00:17<02:47, 59.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12%| | 1.30G/11.2G [00:17<02:46, 59.5MB/s]
#
# Downloading model.safetensors:  78%|█████▍ | 2.18G/2.78G [00:19<00:16, 36.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12%| | 1.31G/11.2G [00:18<06:34, 25.1MB/s]
#
# Downloading model.safetensors:  79%|█████▌ | 2.19G/2.78G [00:19<00:14, 39.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12%| | 1.32G/11.2G [00:18<05:29, 30.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12%| | 1.33G/11.2G [00:18<04:30, 36.5MB/s]
#
# Downloading model.safetensors:  79%|█████▌ | 2.20G/2.78G [00:19<00:12, 44.7MB/s]
#
# Downloading model.safetensors:  80%|█████▌ | 2.21G/2.78G [00:19<00:11, 50.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12%| | 1.34G/11.2G [00:19<03:49, 43.1MB/s]
#
# Downloading model.safetensors:  80%|█████▌ | 2.22G/2.78G [00:21<00:27, 20.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12%| | 1.35G/11.2G [00:20<09:12, 17.9MB/s]
#
# Downloading model.safetensors:  80%|█████▋ | 2.23G/2.78G [00:21<00:21, 25.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12%| | 1.36G/11.2G [00:20<07:06, 23.1MB/s]
#
# Downloading model.safetensors:  81%|█████▋ | 2.25G/2.78G [00:21<00:13, 39.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12%| | 1.38G/11.2G [00:20<04:32, 36.1MB/s]
#
# Downloading model.safetensors:  82%|█████▋ | 2.26G/2.78G [00:21<00:11, 43.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12%| | 1.39G/11.2G [00:20<03:57, 41.4MB/s]
#
# Downloading model.safetensors:  82%|█████▊ | 2.29G/2.78G [00:21<00:08, 60.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13%|▏| 1.41G/11.2G [00:21<03:27, 47.2MB/s]
#
# Downloading model.safetensors:  83%|█████▊ | 2.31G/2.78G [00:21<00:06, 77.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13%|▏| 1.42G/11.2G [00:21<03:18, 49.3MB/s]
#
# Downloading model.safetensors:  84%|█████▊ | 2.33G/2.78G [00:21<00:04, 96.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13%|▏| 1.43G/11.2G [00:21<02:58, 54.9MB/s]
#
# Downloading model.safetensors:  85%|██████▊ | 2.35G/2.78G [00:21<00:03, 114MB/s]
#
# Downloading model.safetensors:  85%|██████▊ | 2.37G/2.78G [00:22<00:03, 130MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13%|▏| 1.45G/11.2G [00:21<02:17, 71.3MB/s]
#
# Downloading model.safetensors:  86%|██████▉ | 2.39G/2.78G [00:22<00:02, 143MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13%|▏| 1.46G/11.2G [00:21<02:09, 75.3MB/s]
#
# Downloading model.safetensors:  87%|██████▉ | 2.41G/2.78G [00:22<00:02, 151MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13%|▏| 1.48G/11.2G [00:23<06:14, 26.0MB/s]
#
# Downloading model.safetensors:  88%|██████▏| 2.43G/2.78G [00:23<00:09, 35.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13%|▏| 1.49G/11.2G [00:23<05:16, 30.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13%|▏| 1.50G/11.2G [00:23<04:22, 37.1MB/s]
#
# Downloading model.safetensors:  88%|██████▏| 2.45G/2.78G [00:24<00:07, 45.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13%|▏| 1.51G/11.2G [00:23<03:39, 44.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  14%|▏| 1.52G/11.2G [00:23<03:05, 52.2MB/s]
#
# Downloading model.safetensors:  89%|██████▏| 2.47G/2.78G [00:24<00:05, 54.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  14%|▏| 1.54G/11.2G [00:23<02:20, 68.7MB/s]
#
# Downloading model.safetensors:  90%|██████▎| 2.50G/2.78G [00:24<00:04, 64.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  14%|▏| 1.55G/11.2G [00:24<02:12, 73.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  14%|▏| 1.56G/11.2G [00:24<02:03, 78.5MB/s]
#
# Downloading model.safetensors:  91%|██████▎| 2.52G/2.78G [00:24<00:03, 74.6MB/s]
#
# Downloading model.safetensors:  91%|██████▍| 2.54G/2.78G [00:24<00:02, 90.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  14%|▏| 1.58G/11.2G [00:24<01:37, 99.1MB/s]
#
# Downloading model.safetensors:  92%|███████▎| 2.56G/2.78G [00:24<00:02, 107MB/s]
#
# Downloading model.safetensors:  93%|███████▍| 2.58G/2.78G [00:25<00:01, 123MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  14%|▏| 1.60G/11.2G [00:24<02:07, 75.3MB/s]
#
# Downloading model.safetensors:  94%|███████▍| 2.60G/2.78G [00:25<00:01, 112MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  14%|▏| 1.61G/11.2G [00:24<02:01, 79.1MB/s]
#
# Downloading model.safetensors:  94%|███████▌| 2.62G/2.78G [00:25<00:01, 128MB/s]
#
# Downloading model.safetensors:  95%|███████▌| 2.64G/2.78G [00:25<00:00, 143MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  14%|▏| 1.63G/11.2G [00:24<02:19, 68.6MB/s]
#
# Downloading model.safetensors:  96%|███████▋| 2.66G/2.78G [00:25<00:00, 155MB/s]
#
# Downloading model.safetensors:  97%|███████▋| 2.68G/2.78G [00:25<00:00, 167MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:
6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  97%|▉| 10.8G/11.2G [02:24<00:04, 88.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  97%|▉| 10.8G/11.2G [02:24<00:04, 82.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  97%|▉| 10.9G/11.2G [02:25<00:05, 69.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  97%|▉| 10.9G/11.2G [02:25<00:05, 68.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  97%|▉| 10.9G/11.2G [02:25<00:04, 73.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  97%|▉| 10.9G/11.2G [02:25<00:03, 88.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  97%|▉| 10.9G/11.2G [02:25<00:03, 89.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  98%|█▉| 10.9G/11.2G [02:26<00:02, 102MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  98%|█▉| 11.0G/11.2G [02:26<00:02, 114MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  98%|▉| 11.0G/11.2G [02:26<00:02, 88.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  98%|▉| 11.0G/11.2G [02:26<00:02, 90.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  98%|▉| 11.0G/11.2G [02:27<00:02, 86.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  98%|▉| 11.0G/11.2G [02:27<00:02, 72.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  98%|▉| 11.0G/11.2G [02:27<00:02, 60.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  99%|▉| 11.1G/11.2G [02:27<00:01, 79.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  99%|▉| 11.1G/11.2G [02:27<00:01, 77.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  99%|▉| 11.1G/11.2G [02:27<00:01, 77.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  99%|▉| 11.1G/11.2G [02:28<00:01, 88.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  99%|█▉| 11.1G/11.2G [02:28<00:00, 102MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  99%|▉| 11.1G/11.2G [02:28<00:00, 91.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  99%|▉| 11.2G/11.2G [02:28<00:00, 92.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors: 100%|▉| 11.2G/11.2G [02:28<00:00, 96.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors: 100%|█▉| 11.2G/11.2G [02:29<00:00, 102MB/s]
#
#
#
# Downloading (…)ch_model.safetensors: 100%|█| 11.2G/11.2G [02:29<00:00, 75.1MB/s]
# Fetching 18 files: 100%|████████████████████████| 18/18 [02:30<00:00,  8.34s/it]
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]

# %%
#@title Download a LoRA

# %cd $HOTSHOT_PATH
# %cd lora

import requests

url = 'https://civitai.com/api/download/models/163063'  #@param {type:"string"}
lora_file_name = 'woolify.safetensors' #@param {type:"string"}

r = requests.get(url, allow_redirects=True)
with open(lora_file_name, 'wb') as f:
    f.write(r.content)

print('Downloaded ' + lora_file_name)

# %%
#@title Download gif

# %cd $HOTSHOT_PATH
# %cd input

import requests
from PIL import Image
from io import BytesIO

url='https://media2.giphy.com/media/v1.Y2lkPTc5MGI3NjExZGFiY2M1bnl0bjVrNjdxYWViZTZsZHZwOXNncmNjbGhuam9lM3F0ZSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/0VKbVY3N0VW0ZegLbe/giphy.gif' #@param {type:"string"}
gif_name = 'bunny.gif' #@param {type:"string"}

r = requests.get(url, allow_redirects=True)
with open(gif_name, 'wb') as f:
    f.write(r.content)

# Show the frame count
im = Image.open(gif_name)
print(f'{gif_name} has {im.n_frames} frames')

# %%
#@title Download webp and convert to gif

# %cd $HOTSHOT_PATH
# %cd input

import requests
from PIL import Image
from io import BytesIO

url='' #@param {type:"string"}
gif_name = '' #@param {type:"string"}

r = requests.get(url, allow_redirects=True)
with open('temp.webp', 'wb') as f:
    f.write(r.content)

cmd = f'convert temp.webp {gif_name}'
get_ipython().system(cmd)

# Show the frame count
im = Image.open(gif_name)
print(f'{gif_name} has {im.n_frames} frames')
